# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
bull_dict = dict()
TROC_Bear_returns_dict = dict()
output_to_csv1 = []
output_to_csv2 = []

# %%
# #running the simple and exponential moving average tests
# for i in range(1, 50):
#     df = pd.read_csv('Tether.csv')
#     df.columns = df.columns.str.strip()
#     df['Pct Change'] = df['price'].pct_change(periods=364)
#     df['TROC'] = (df['tether'].pct_change(periods=i)*100)
#     print(i)
#     #TROC Thresholds change
#     for x in [x * 0.1 for x in range(-220, 400)]:
#         dfbull = df[df['TROC'] >= x]
#         dfbear = df[df['TROC'] <= x]
#         print(x)

# %%
#running the simple and exponential moving average tests
for i in range(1, 50):
    df = pd.read_csv('Tether.csv')
    df.columns = df.columns.str.strip()
    df['Pct Change'] = df['price'].pct_change(periods=364)
    df['TROC'] = (df['tether'].pct_change(periods=i)*100)
    #TROC Thresholds change
    for x in [x * 0.1 for x in range(-220, 400)]:
        dfbull = df[df['TROC'] >= x]
        dfbear = df[df['TROC'] <= x]
        bullaverage = dfbull['Pct Change'].mean()
        print("Average 1 year return is", bullaverage, "using ", i, "Tether ROC days and ", x, " Tether ROC threshold.")
        bull_dict[i] = bullaverage
# Out:
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -22.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.900000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.700000000000003  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.6  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.400000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.200000000000003  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.1  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -21.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.900000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.700000000000003  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.6  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.400000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.200000000000003  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.1  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -20.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.900000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.700000000000003  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.6  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.400000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.200000000000003  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.1  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -19.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.900000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.7  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.6  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.400000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.2  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.1  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -18.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.900000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.7  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.6  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.400000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.2  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.1  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -17.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.900000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.7  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.6  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.400000000000002  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.2  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.1  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -16.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.9  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.4  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.100000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -15.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.9  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.4  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.100000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -14.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.9  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.4  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.100000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -13.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.9  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.4  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.100000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -12.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.9  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.4  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.100000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -11.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.9  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.5  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.4  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.3  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.100000000000001  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -10.0  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -9.9  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -9.8  Tether ROC threshold.
# Average 1 year return is 1.8311027112113736 using  1 Tether ROC days and  -9.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.829321098427594 using  1 Tether ROC days and  -9.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.829321098427594 using  1 Tether ROC days and  -9.5  Tether ROC threshold.
# Average 1 year return is 1.8269905121631966 using  1 Tether ROC days and  -9.4  Tether ROC threshold.
# Average 1 year return is 1.8269905121631966 using  1 Tether ROC days and  -9.3  Tether ROC threshold.
# Average 1 year return is 1.8269905121631966 using  1 Tether ROC days and  -9.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.823671268921903 using  1 Tether ROC days and  -9.1  Tether ROC threshold.
# Average 1 year return is 1.823671268921903 using  1 Tether ROC days and  -9.0  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.9  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.8  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.6  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.5  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.4  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.3  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.1  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -8.0  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.9  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.800000000000001  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.7  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.6000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.5  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.4  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.300000000000001  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.2  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.1000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -7.0  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.9  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.800000000000001  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.7  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.6000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.5  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.4  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.300000000000001  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.2  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.1000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -6.0  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -5.9  Tether ROC threshold.
# Average 1 year return is 1.8170317481339149 using  1 Tether ROC days and  -5.800000000000001  Tether ROC threshold.
# Average 1 year return is 1.8148991535789936 using  1 Tether ROC days and  -5.7  Tether ROC threshold.
# Average 1 year return is 1.8148991535789936 using  1 Tether ROC days and  -5.6000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8148991535789936 using  1 Tether ROC days and  -5.5  Tether ROC threshold.
# Average 1 year return is 1.8148991535789936 using  1 Tether ROC days and  -5.4  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -5.300000000000001  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -5.2  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -5.1000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -5.0  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.9  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.800000000000001  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.7  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.6000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.5  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.4  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.3  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.2  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.1000000000000005  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -4.0  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.9000000000000004  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.8000000000000003  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.7  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.6  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.5  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.4000000000000004  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.3000000000000003  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.2  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.1  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -3.0  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.9000000000000004  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.8000000000000003  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.7  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.6  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.5  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.4000000000000004  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.3000000000000003  Tether ROC threshold.
# Average 1 year return is 1.8103929090750497 using  1 Tether ROC days and  -2.2  Tether ROC threshold.
# Average 1 year return is 1.8086926600456203 using  1 Tether ROC days and  -2.1  Tether ROC threshold.
# Average 1 year return is 1.8086926600456203 using  1 Tether ROC days and  -2.0  Tether ROC threshold.
# Average 1 year return is 1.8086926600456203 using  1 Tether ROC days and  -1.9000000000000001  Tether ROC threshold.
# Average 1 year return is 1.80987370922067 using  1 Tether ROC days and  -1.8  Tether ROC threshold.
# Average 1 year return is 1.80987370922067 using  1 Tether ROC days and  -1.7000000000000002  Tether ROC threshold.
# Average 1 year return is 1.8096064794967264 using  1 Tether ROC days and  -1.6  Tether ROC threshold.
# Average 1 year return is 1.8111717559560436 using  1 Tether ROC days and  -1.5  Tether ROC threshold.
# Average 1 year return is 1.8111717559560436 using  1 Tether ROC days and  -1.4000000000000001  Tether ROC threshold.
# Average 1 year return is 1.8111717559560436 using  1 Tether ROC days and  -1.3  Tether ROC threshold.
# Average 1 year return is 1.8121332964634111 using  1 Tether ROC days and  -1.2000000000000002  Tether ROC threshold.
# Average 1 year return is 1.813803261248001 using  1 Tether ROC days and  -1.1  Tether ROC threshold.
# Average 1 year return is 1.8134746571075162 using  1 Tether ROC days and  -1.0  Tether ROC threshold.
# Average 1 year return is 1.8134746571075162 using  1 Tether ROC days and  -0.9  Tether ROC threshold.
# Average 1 year return is 1.8134746571075162 using  1 Tether ROC days and  -0.8  Tether ROC threshold.
# Average 1 year return is 1.8134746571075162 using  1 Tether ROC days and  -0.7000000000000001  Tether ROC threshold.
# Average 1 year return is 1.8134746571075162 using  1 Tether ROC days and  -0.6000000000000001  Tether ROC threshold.
# Average 1 year return is 1.809714602785489 using  1 Tether ROC days and  -0.5  Tether ROC threshold.
# Average 1 year return is 1.8118384767629319 using  1 Tether ROC days and  -0.4  Tether ROC threshold.
# Average 1 year return is 1.8135107525320693 using  1 Tether ROC days and  -0.30000000000000004  Tether ROC threshold.
# Average 1 year return is 1.831246988417365 using  1 Tether ROC days and  -0.2  Tether ROC threshold.
# Average 1 year return is 1.8885879281657967 using  1 Tether ROC days and  -0.1  Tether ROC threshold.
# Average 1 year return is 2.0698003920719 using  1 Tether ROC days and  0.0  Tether ROC threshold.
# Average 1 year return is 2.3302663722694517 using  1 Tether ROC days and  0.1  Tether ROC threshold.
# Average 1 year return is 2.542964195088088 using  1 Tether ROC days and  0.2  Tether ROC threshold.
# Average 1 year return is 2.7811959541722646 using  1 Tether ROC days and  0.30000000000000004  Tether ROC threshold.
# Average 1 year return is 2.884651951655179 using  1 Tether ROC days and  0.4  Tether ROC threshold.
# Average 1 year return is 2.890479363680422 using  1 Tether ROC days and  0.5  Tether ROC threshold.
# Average 1 year return is 3.0534929574597576 using  1 Tether ROC days and  0.6000000000000001  Tether ROC threshold.
# Average 1 year return is 3.1728899509879405 using  1 Tether ROC days and  0.7000000000000001  Tether ROC threshold.
# Average 1 year return is 3.1649937916299247 using  1 Tether ROC days and  0.8  Tether ROC threshold.
# Average 1 year return is 3.2484639312524246 using  1 Tether ROC days and  0.9  Tether ROC threshold.
# Average 1 year return is 3.3004525154642628 using  1 Tether ROC days and  1.0  Tether ROC threshold.
# Average 1 year return is 3.2909765663620125 using  1 Tether ROC days and  1.1  Tether ROC threshold.
# Average 1 year return is 3.187745683281347 using  1 Tether ROC days and  1.2000000000000002  Tether ROC threshold.
# Average 1 year return is 3.1839025316505083 using  1 Tether ROC days and  1.3  Tether ROC threshold.
# Average 1 year return is 3.168908981310578 using  1 Tether ROC days and  1.4000000000000001  Tether ROC threshold.
# Average 1 year return is 3.340073909540719 using  1 Tether ROC days and  1.5  Tether ROC threshold.
# Average 1 year return is 3.193364117273661 using  1 Tether ROC days and  1.6  Tether ROC threshold.
# Average 1 year return is 3.116934443782538 using  1 Tether ROC days and  1.7000000000000002  Tether ROC threshold.
# Average 1 year return is 3.211250085864201 using  1 Tether ROC days and  1.8  Tether ROC threshold.
# Average 1 year return is 3.344102440585508 using  1 Tether ROC days and  1.9000000000000001  Tether ROC threshold.
# Average 1 year return is 3.213206710776331 using  1 Tether ROC days and  2.0  Tether ROC threshold.
# Average 1 year return is 3.1394859896202023 using  1 Tether ROC days and  2.1  Tether ROC threshold.
# Average 1 year return is 2.895916708649039 using  1 Tether ROC days and  2.2  Tether ROC threshold.
# Average 1 year return is 2.8867186724787377 using  1 Tether ROC days and  2.3000000000000003  Tether ROC threshold.
# Average 1 year return is 2.6840802557262706 using  1 Tether ROC days and  2.4000000000000004  Tether ROC threshold.
# Average 1 year return is 2.6840802557262706 using  1 Tether ROC days and  2.5  Tether ROC threshold.
# Average 1 year return is 2.6840802557262706 using  1 Tether ROC days and  2.6  Tether ROC threshold.
# Average 1 year return is 2.6840802557262706 using  1 Tether ROC days and  2.7  Tether ROC threshold.
# Average 1 year return is 2.6840802557262706 using  1 Tether ROC days and  2.8000000000000003  Tether ROC threshold.
# Average 1 year return is 2.6840802557262706 using  1 Tether ROC days and  2.9000000000000004  Tether ROC threshold.
# Average 1 year return is 2.564285209132163 using  1 Tether ROC days and  3.0  Tether ROC threshold.
# Average 1 year return is 2.520198972697594 using  1 Tether ROC days and  3.1  Tether ROC threshold.
# Average 1 year return is 2.520198972697594 using  1 Tether ROC days and  3.2  Tether ROC threshold.
# Average 1 year return is 2.6268046785774275 using  1 Tether ROC days and  3.3000000000000003  Tether ROC threshold.
# Average 1 year return is 2.6268046785774275 using  1 Tether ROC days and  3.4000000000000004  Tether ROC threshold.
# Average 1 year return is 2.4792938451044755 using  1 Tether ROC days and  3.5  Tether ROC threshold.
# Average 1 year return is 2.4792938451044755 using  1 Tether ROC days and  3.6  Tether ROC threshold.
# Average 1 year return is 2.4792938451044755 using  1 Tether ROC days and  3.7  Tether ROC threshold.
# Average 1 year return is 2.420889259577062 using  1 Tether ROC days and  3.8000000000000003  Tether ROC threshold.
# Average 1 year return is 2.420889259577062 using  1 Tether ROC days and  3.9000000000000004  Tether ROC threshold.
# Average 1 year return is 2.4069500728375184 using  1 Tether ROC days and  4.0  Tether ROC threshold.
# Average 1 year return is 2.4069500728375184 using  1 Tether ROC days and  4.1000000000000005  Tether ROC threshold.
# Average 1 year return is 2.4069500728375184 using  1 Tether ROC days and  4.2  Tether ROC threshold.
# Average 1 year return is 2.4069500728375184 using  1 Tether ROC days and  4.3  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  4.4  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  4.5  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  4.6000000000000005  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  4.7  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  4.800000000000001  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  4.9  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  5.0  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  5.1000000000000005  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  5.2  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  5.300000000000001  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  5.4  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  5.5  Tether ROC threshold.
# Average 1 year return is 2.542295647535355 using  1 Tether ROC days and  5.6000000000000005  Tether ROC threshold.
# Average 1 year return is 2.4684408683979657 using  1 Tether ROC days and  5.7  Tether ROC threshold.
# Average 1 year return is 2.4684408683979657 using  1 Tether ROC days and  5.800000000000001  Tether ROC threshold.
# Average 1 year return is 2.4684408683979657 using  1 Tether ROC days and  5.9  Tether ROC threshold.
# Average 1 year return is 2.4684408683979657 using  1 Tether ROC days and  6.0  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.1000000000000005  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.2  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.300000000000001  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.4  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.5  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.6000000000000005  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.7  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.800000000000001  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  6.9  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.0  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.1000000000000005  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.2  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.300000000000001  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.4  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.5  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.6000000000000005  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.7  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.800000000000001  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  7.9  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.0  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.1  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.200000000000001  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.3  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.4  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.5  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.6  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.700000000000001  Tether ROC threshold.
# Average 1 year return is 2.363067124283555 using  1 Tether ROC days and  8.8  Tether ROC threshold.
# Average 1 year return is 2.5619899644054467 using  1 Tether ROC days and  8.9  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.0  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.1  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.200000000000001  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.3  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.4  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.5  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.600000000000001  Tether ROC threshold.
# Average 1 year return is 2.4655324577657662 using  1 Tether ROC days and  9.700000000000001  Tether ROC threshold.
# Average 1 year return is 2.3197364392285182 using  1 Tether ROC days and  9.8  Tether ROC threshold.
# Average 1 year return is 2.1488722594636673 using  1 Tether ROC days and  9.9  Tether ROC threshold.
# Average 1 year return is 2.1488722594636673 using  1 Tether ROC days and  10.0  Tether ROC threshold.
# Average 1 year return is 1.9970410540204586 using  1 Tether ROC days and  10.100000000000001  Tether ROC threshold.
# Average 1 year return is 1.8024933603073532 using  1 Tether ROC days and  10.200000000000001  Tether ROC threshold.
# Average 1 year return is 1.5509409457608505 using  1 Tether ROC days and  10.3  Tether ROC threshold.
# Average 1 year return is 1.0992457238349596 using  1 Tether ROC days and  10.4  Tether ROC threshold.
# Average 1 year return is 1.0992457238349596 using  1 Tether ROC days and  10.5  Tether ROC threshold.
# Average 1 year return is 1.0992457238349596 using  1 Tether ROC days and  10.600000000000001  Tether ROC threshold.
# Average 1 year return is 1.0992457238349596 using  1 Tether ROC days and  10.700000000000001  Tether ROC threshold.
# Average 1 year return is 1.0992457238349596 using  1 Tether ROC days and  10.8  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  10.9  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.0  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.100000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.200000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.3  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.4  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.5  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.600000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.700000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.8  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  11.9  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.0  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.100000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.200000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.3  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.4  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.5  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.600000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.700000000000001  Tether ROC threshold.
# Average 1 year return is 0.3999883533754405 using  1 Tether ROC days and  12.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  12.9  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.100000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.200000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.4  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.600000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.700000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  13.9  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.100000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.200000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.4  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.600000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.700000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  14.9  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.100000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.200000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.4  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.600000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.700000000000001  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  15.9  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.1  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.2  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.400000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.6  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.7  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  16.900000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.1  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.2  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.400000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.6  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.7  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  17.900000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.1  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.2  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.400000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.6  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.7  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  18.900000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.1  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.200000000000003  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.400000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.6  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.700000000000003  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  19.900000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.1  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.200000000000003  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.400000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.6  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.700000000000003  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  20.900000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.1  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.200000000000003  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.400000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.6  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.700000000000003  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.8  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  21.900000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.0  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.1  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.200000000000003  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.3  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.400000000000002  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.5  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.6  Tether ROC threshold.
# Average 1 year return is 0.22486653527629819 using  1 Tether ROC days and  22.700000000000003  Tether ROC threshold.
# ...
# Average 1 year return is 2.389981186926108 using  49 Tether ROC days and  25.1  Tether ROC threshold.
# Average 1 year return is 2.387707761611921 using  49 Tether ROC days and  25.200000000000003  Tether ROC threshold.
# Average 1 year return is 2.387707761611921 using  49 Tether ROC days and  25.3  Tether ROC threshold.
# Average 1 year return is 2.387707761611921 using  49 Tether ROC days and  25.400000000000002  Tether ROC threshold.
# Average 1 year return is 2.4009410097780766 using  49 Tether ROC days and  25.5  Tether ROC threshold.
# Average 1 year return is 2.4009410097780766 using  49 Tether ROC days and  25.6  Tether ROC threshold.
# Average 1 year return is 2.4009410097780766 using  49 Tether ROC days and  25.700000000000003  Tether ROC threshold.
# Average 1 year return is 2.4064508846503503 using  49 Tether ROC days and  25.8  Tether ROC threshold.
# Average 1 year return is 2.4064508846503503 using  49 Tether ROC days and  25.900000000000002  Tether ROC threshold.
# Average 1 year return is 2.426208238768606 using  49 Tether ROC days and  26.0  Tether ROC threshold.
# Average 1 year return is 2.433321365011692 using  49 Tether ROC days and  26.1  Tether ROC threshold.
# Average 1 year return is 2.4320734092344076 using  49 Tether ROC days and  26.200000000000003  Tether ROC threshold.
# Average 1 year return is 2.4320734092344076 using  49 Tether ROC days and  26.3  Tether ROC threshold.
# Average 1 year return is 2.4374946196497937 using  49 Tether ROC days and  26.400000000000002  Tether ROC threshold.
# Average 1 year return is 2.442961309460825 using  49 Tether ROC days and  26.5  Tether ROC threshold.
# Average 1 year return is 2.440050997209689 using  49 Tether ROC days and  26.6  Tether ROC threshold.
# Average 1 year return is 2.440050997209689 using  49 Tether ROC days and  26.700000000000003  Tether ROC threshold.
# Average 1 year return is 2.440050997209689 using  49 Tether ROC days and  26.8  Tether ROC threshold.
# Average 1 year return is 2.445895538456712 using  49 Tether ROC days and  26.900000000000002  Tether ROC threshold.
# Average 1 year return is 2.444295177854479 using  49 Tether ROC days and  27.0  Tether ROC threshold.
# Average 1 year return is 2.455571729529851 using  49 Tether ROC days and  27.1  Tether ROC threshold.
# Average 1 year return is 2.4573408273951594 using  49 Tether ROC days and  27.200000000000003  Tether ROC threshold.
# Average 1 year return is 2.4549058459687125 using  49 Tether ROC days and  27.3  Tether ROC threshold.
# Average 1 year return is 2.4744181530267957 using  49 Tether ROC days and  27.400000000000002  Tether ROC threshold.
# Average 1 year return is 2.4799235298059013 using  49 Tether ROC days and  27.5  Tether ROC threshold.
# Average 1 year return is 2.493229521157745 using  49 Tether ROC days and  27.6  Tether ROC threshold.
# Average 1 year return is 2.490028609689412 using  49 Tether ROC days and  27.700000000000003  Tether ROC threshold.
# Average 1 year return is 2.490028609689412 using  49 Tether ROC days and  27.8  Tether ROC threshold.
# Average 1 year return is 2.494875265553182 using  49 Tether ROC days and  27.900000000000002  Tether ROC threshold.
# Average 1 year return is 2.4955838141326163 using  49 Tether ROC days and  28.0  Tether ROC threshold.
# Average 1 year return is 2.4955838141326163 using  49 Tether ROC days and  28.1  Tether ROC threshold.
# Average 1 year return is 2.5071669121311007 using  49 Tether ROC days and  28.200000000000003  Tether ROC threshold.
# Average 1 year return is 2.5334617847700103 using  49 Tether ROC days and  28.3  Tether ROC threshold.
# Average 1 year return is 2.5334617847700103 using  49 Tether ROC days and  28.400000000000002  Tether ROC threshold.
# Average 1 year return is 2.5404181766048968 using  49 Tether ROC days and  28.5  Tether ROC threshold.
# Average 1 year return is 2.5536290322885087 using  49 Tether ROC days and  28.6  Tether ROC threshold.
# Average 1 year return is 2.559356959096978 using  49 Tether ROC days and  28.700000000000003  Tether ROC threshold.
# Average 1 year return is 2.559356959096978 using  49 Tether ROC days and  28.8  Tether ROC threshold.
# Average 1 year return is 2.5565206872743467 using  49 Tether ROC days and  28.900000000000002  Tether ROC threshold.
# Average 1 year return is 2.562092207320841 using  49 Tether ROC days and  29.0  Tether ROC threshold.
# Average 1 year return is 2.563662445853668 using  49 Tether ROC days and  29.1  Tether ROC threshold.
# Average 1 year return is 2.5673871404465 using  49 Tether ROC days and  29.200000000000003  Tether ROC threshold.
# Average 1 year return is 2.5673871404465 using  49 Tether ROC days and  29.3  Tether ROC threshold.
# Average 1 year return is 2.5673871404465 using  49 Tether ROC days and  29.400000000000002  Tether ROC threshold.
# Average 1 year return is 2.5549066249995036 using  49 Tether ROC days and  29.5  Tether ROC threshold.
# Average 1 year return is 2.5549066249995036 using  49 Tether ROC days and  29.6  Tether ROC threshold.
# Average 1 year return is 2.5538372876234217 using  49 Tether ROC days and  29.700000000000003  Tether ROC threshold.
# Average 1 year return is 2.5688508857702157 using  49 Tether ROC days and  29.8  Tether ROC threshold.
# Average 1 year return is 2.5688508857702157 using  49 Tether ROC days and  29.900000000000002  Tether ROC threshold.
# Average 1 year return is 2.5480821245996554 using  49 Tether ROC days and  30.0  Tether ROC threshold.
# Average 1 year return is 2.5476287307033965 using  49 Tether ROC days and  30.1  Tether ROC threshold.
# Average 1 year return is 2.5676929318056523 using  49 Tether ROC days and  30.200000000000003  Tether ROC threshold.
# Average 1 year return is 2.5676929318056523 using  49 Tether ROC days and  30.3  Tether ROC threshold.
# Average 1 year return is 2.5676929318056523 using  49 Tether ROC days and  30.400000000000002  Tether ROC threshold.
# Average 1 year return is 2.549801212130637 using  49 Tether ROC days and  30.5  Tether ROC threshold.
# Average 1 year return is 2.536663900680758 using  49 Tether ROC days and  30.6  Tether ROC threshold.
# Average 1 year return is 2.543422262583114 using  49 Tether ROC days and  30.700000000000003  Tether ROC threshold.
# Average 1 year return is 2.543422262583114 using  49 Tether ROC days and  30.8  Tether ROC threshold.
# Average 1 year return is 2.543422262583114 using  49 Tether ROC days and  30.900000000000002  Tether ROC threshold.
# Average 1 year return is 2.550316991337166 using  49 Tether ROC days and  31.0  Tether ROC threshold.
# Average 1 year return is 2.549262245748819 using  49 Tether ROC days and  31.1  Tether ROC threshold.
# Average 1 year return is 2.561593207064809 using  49 Tether ROC days and  31.200000000000003  Tether ROC threshold.
# Average 1 year return is 2.561593207064809 using  49 Tether ROC days and  31.3  Tether ROC threshold.
# Average 1 year return is 2.5389978815824703 using  49 Tether ROC days and  31.400000000000002  Tether ROC threshold.
# Average 1 year return is 2.5389978815824703 using  49 Tether ROC days and  31.5  Tether ROC threshold.
# Average 1 year return is 2.5389978815824703 using  49 Tether ROC days and  31.6  Tether ROC threshold.
# Average 1 year return is 2.522131414582857 using  49 Tether ROC days and  31.700000000000003  Tether ROC threshold.
# Average 1 year return is 2.522131414582857 using  49 Tether ROC days and  31.8  Tether ROC threshold.
# Average 1 year return is 2.522131414582857 using  49 Tether ROC days and  31.900000000000002  Tether ROC threshold.
# Average 1 year return is 2.522131414582857 using  49 Tether ROC days and  32.0  Tether ROC threshold.
# Average 1 year return is 2.5035643283079367 using  49 Tether ROC days and  32.1  Tether ROC threshold.
# Average 1 year return is 2.483931970912497 using  49 Tether ROC days and  32.2  Tether ROC threshold.
# Average 1 year return is 2.483931970912497 using  49 Tether ROC days and  32.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.483931970912497 using  49 Tether ROC days and  32.4  Tether ROC threshold.
# Average 1 year return is 2.4639601891057805 using  49 Tether ROC days and  32.5  Tether ROC threshold.
# Average 1 year return is 2.470270443368598 using  49 Tether ROC days and  32.6  Tether ROC threshold.
# Average 1 year return is 2.454105479725106 using  49 Tether ROC days and  32.7  Tether ROC threshold.
# Average 1 year return is 2.4622537445453387 using  49 Tether ROC days and  32.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.4792590334373243 using  49 Tether ROC days and  32.9  Tether ROC threshold.
# Average 1 year return is 2.487698177698681 using  49 Tether ROC days and  33.0  Tether ROC threshold.
# Average 1 year return is 2.4870175486728785 using  49 Tether ROC days and  33.1  Tether ROC threshold.
# Average 1 year return is 2.4956492987229244 using  49 Tether ROC days and  33.2  Tether ROC threshold.
# Average 1 year return is 2.4956492987229244 using  49 Tether ROC days and  33.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.454932528256581 using  49 Tether ROC days and  33.4  Tether ROC threshold.
# Average 1 year return is 2.454932528256581 using  49 Tether ROC days and  33.5  Tether ROC threshold.
# Average 1 year return is 2.433319841945229 using  49 Tether ROC days and  33.6  Tether ROC threshold.
# Average 1 year return is 2.413323691670959 using  49 Tether ROC days and  33.7  Tether ROC threshold.
# Average 1 year return is 2.413323691670959 using  49 Tether ROC days and  33.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.413323691670959 using  49 Tether ROC days and  33.9  Tether ROC threshold.
# Average 1 year return is 2.3914489318209364 using  49 Tether ROC days and  34.0  Tether ROC threshold.
# Average 1 year return is 2.378492644885081 using  49 Tether ROC days and  34.1  Tether ROC threshold.
# Average 1 year return is 2.3775272522604025 using  49 Tether ROC days and  34.2  Tether ROC threshold.
# Average 1 year return is 2.3775272522604025 using  49 Tether ROC days and  34.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.354807094488595 using  49 Tether ROC days and  34.4  Tether ROC threshold.
# Average 1 year return is 2.354807094488595 using  49 Tether ROC days and  34.5  Tether ROC threshold.
# Average 1 year return is 2.354807094488595 using  49 Tether ROC days and  34.6  Tether ROC threshold.
# Average 1 year return is 2.352576048731047 using  49 Tether ROC days and  34.7  Tether ROC threshold.
# Average 1 year return is 2.339673912055422 using  49 Tether ROC days and  34.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.3490999557139025 using  49 Tether ROC days and  34.9  Tether ROC threshold.
# Average 1 year return is 2.338314486022621 using  49 Tether ROC days and  35.0  Tether ROC threshold.
# Average 1 year return is 2.338314486022621 using  49 Tether ROC days and  35.1  Tether ROC threshold.
# Average 1 year return is 2.338314486022621 using  49 Tether ROC days and  35.2  Tether ROC threshold.
# Average 1 year return is 2.325138269231933 using  49 Tether ROC days and  35.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.3227942033117506 using  49 Tether ROC days and  35.4  Tether ROC threshold.
# Average 1 year return is 2.3302637986756354 using  49 Tether ROC days and  35.5  Tether ROC threshold.
# Average 1 year return is 2.317227028572133 using  49 Tether ROC days and  35.6  Tether ROC threshold.
# Average 1 year return is 2.287595143710299 using  49 Tether ROC days and  35.7  Tether ROC threshold.
# Average 1 year return is 2.287595143710299 using  49 Tether ROC days and  35.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.295202412657927 using  49 Tether ROC days and  35.9  Tether ROC threshold.
# Average 1 year return is 2.295202412657927 using  49 Tether ROC days and  36.0  Tether ROC threshold.
# Average 1 year return is 2.2793107558621846 using  49 Tether ROC days and  36.1  Tether ROC threshold.
# Average 1 year return is 2.2638448867675645 using  49 Tether ROC days and  36.2  Tether ROC threshold.
# Average 1 year return is 2.2638448867675645 using  49 Tether ROC days and  36.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.2638448867675645 using  49 Tether ROC days and  36.4  Tether ROC threshold.
# Average 1 year return is 2.2377109694921447 using  49 Tether ROC days and  36.5  Tether ROC threshold.
# Average 1 year return is 2.2377109694921447 using  49 Tether ROC days and  36.6  Tether ROC threshold.
# Average 1 year return is 2.2364730733407963 using  49 Tether ROC days and  36.7  Tether ROC threshold.
# Average 1 year return is 2.221253201372383 using  49 Tether ROC days and  36.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.2278380171876253 using  49 Tether ROC days and  36.9  Tether ROC threshold.
# Average 1 year return is 2.2798096730856097 using  49 Tether ROC days and  37.0  Tether ROC threshold.
# Average 1 year return is 2.3578435286909567 using  49 Tether ROC days and  37.1  Tether ROC threshold.
# Average 1 year return is 2.3425390524902028 using  49 Tether ROC days and  37.2  Tether ROC threshold.
# Average 1 year return is 2.365701608943681 using  49 Tether ROC days and  37.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.4386739707552767 using  49 Tether ROC days and  37.4  Tether ROC threshold.
# Average 1 year return is 2.3808169179845518 using  49 Tether ROC days and  37.5  Tether ROC threshold.
# Average 1 year return is 2.402480804485237 using  49 Tether ROC days and  37.6  Tether ROC threshold.
# Average 1 year return is 2.377141511764987 using  49 Tether ROC days and  37.7  Tether ROC threshold.
# Average 1 year return is 2.377141511764987 using  49 Tether ROC days and  37.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.3642534197828406 using  49 Tether ROC days and  37.9  Tether ROC threshold.
# Average 1 year return is 2.3908811151157425 using  49 Tether ROC days and  38.0  Tether ROC threshold.
# Average 1 year return is 2.4299781646471037 using  49 Tether ROC days and  38.1  Tether ROC threshold.
# Average 1 year return is 2.4299781646471037 using  49 Tether ROC days and  38.2  Tether ROC threshold.
# Average 1 year return is 2.438465101009671 using  49 Tether ROC days and  38.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.4530670849819525 using  49 Tether ROC days and  38.400000000000006  Tether ROC threshold.
# Average 1 year return is 2.4335959682971797 using  49 Tether ROC days and  38.5  Tether ROC threshold.
# Average 1 year return is 2.4335959682971797 using  49 Tether ROC days and  38.6  Tether ROC threshold.
# Average 1 year return is 2.4335959682971797 using  49 Tether ROC days and  38.7  Tether ROC threshold.
# Average 1 year return is 2.4307141264635197 using  49 Tether ROC days and  38.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.4139866360765647 using  49 Tether ROC days and  38.900000000000006  Tether ROC threshold.
# Average 1 year return is 2.4139866360765647 using  49 Tether ROC days and  39.0  Tether ROC threshold.
# Average 1 year return is 2.4139866360765647 using  49 Tether ROC days and  39.1  Tether ROC threshold.
# Average 1 year return is 2.4101937159594478 using  49 Tether ROC days and  39.2  Tether ROC threshold.
# Average 1 year return is 2.4101937159594478 using  49 Tether ROC days and  39.300000000000004  Tether ROC threshold.
# Average 1 year return is 2.4101937159594478 using  49 Tether ROC days and  39.400000000000006  Tether ROC threshold.
# Average 1 year return is 2.3950672571555973 using  49 Tether ROC days and  39.5  Tether ROC threshold.
# Average 1 year return is 2.3950672571555973 using  49 Tether ROC days and  39.6  Tether ROC threshold.
# Average 1 year return is 2.3950672571555973 using  49 Tether ROC days and  39.7  Tether ROC threshold.
# Average 1 year return is 2.388635545714025 using  49 Tether ROC days and  39.800000000000004  Tether ROC threshold.
# Average 1 year return is 2.3825911657701506 using  49 Tether ROC days and  39.900000000000006  Tether ROC threshold.

# %%
all_values = bull_dict.values()
max_value = max(all_values)

print(max_value)

print(all_values)
# Out:
# nan
# dict_values([nan, nan, nan, nan, nan, -0.03160958184067464, -0.02291413557974059, -0.013287074292280784, -0.009293823050152666, -0.006026198848277553, -0.006185182195549292, -0.004889406252076488, -0.0033206233012304937, -0.0026894925998611763, 0.00163486047891922, 0.00680986260721553, 0.012783170988806686, 0.016822904567086846, 0.021014635463680327, 0.04039414687487077, 0.05424133642721521, 0.0653598996871306, 0.07933343861410672, 0.09074643023323681, 0.10714169419901862, 0.11819326415685559, 0.12833048988291726, 0.13744008090295948, 0.14151420824441255, 0.37157072826914966, 0.5510395416091932, 0.7103403311470382, 0.917673022174669, 1.1435857780618524, 1.164732330524551, 1.1852948305924176, 1.535276233278844, 1.8298127374579636, 2.0336929217753412, 2.0752682023120683, 2.1717381277407792, 2.2271082492391225, 2.225870159810182, 2.266690075436826, 2.3071190507879296, 2.3442592121255066, 2.3628198676125787, 2.3632256069988222, 2.3825911657701506])

# %%
#running the simple and exponential moving average tests
for i in range(1, 50):
    df = pd.read_csv('Tether.csv')
    df.columns = df.columns.str.strip()
    df['Pct Change'] = df['price'].pct_change()
    df['TROC'] = df['tether'].diff(periods=i)
    #TROC Thresholds change
    for x in [x * 0.1 for x in range(-220, 400)]:
        df['TROC Bull data'] = df['TROC'] >= x
        df['TROC Bear data'] = df['TROC'] <= x
        #actual model
        df['Buy and Hold'] = 100*(1+df['Pct Change']).cumprod()
        df['TROC Bull'] = 100*(1+df['TROC Bull data'].shift(1)*df['Pct Change']).cumprod()
        df['TROC Bear'] = 100*(1+df['TROC Bear data'].shift(1)*df['Pct Change']).cumprod()
        #TROC BULL MODEL
        TROC_Bull_start = df['TROC Bull'].iloc[300]
        TROC_Bull_end = df['TROC Bull'].iloc[-1]
        years = (df['TROC Bull'].count()+1-300)/252
        TROC_Bull_average_return = (TROC_Bull_end/TROC_Bull_start)**(1/years)-1
        TROC_Bull_returns_dict[i] = TROC_Bull_average_return
        print('This TROC Bull model yields an average of', TROC_Bull_average_return, 'per year', 'using', i, 'days', 'and', x, 'TROC Threshold')
        output_to_csv1.append(('The ' + str(i) + ' ROC',TROC_Bull_average_return ))
        #TROC BEAR MODEL
        TROC_Bear_start = df['TROC Bear'].iloc[300]
        TROC_Bear_end = df['TROC Bear'].iloc[-1]
        TROC_Bear_average_return = (TROC_Bear_end/TROC_Bear_start)**(1/years)-1
        TROC_Bear_returns_dict[i] = TROC_Bear_average_return
        print('This TROC Bear model yields an average of', TROC_Bear_average_return, 'per year', 'using', i, 'days', 'and', x, 'TROC Threshold')
        output_to_csv2.append(('The ' + str(i) + ' ROC',TROC_Bear_average_return ))
        #buy and hold BTC result
        start_BTC = df['price'].iloc[300]
        end_BTC = df['price'].iloc[-1]
        BTC_average_return = (end_BTC/start_BTC)**(1/years)-1

# %%
df['TROC'].head()

# %%
print('Buy and hold average return is', BTC_average_return, 'per year')
out_df1 = pd.DataFrame(output_to_csv1, columns=['TROC Bull', 'average_return', ''])
out_df2 = pd.DataFrame(output_to_csv2, columns=['TROC Bear', 'average_return'])

# %%
#find best ROC Bull returns
max_ROC_Bull_return = 0
max_ROC_Bull_days = 0
max_ROC_Bull_TROC_Thresh = 0
for key in TROC_Bull_returns_dict:
    if TROC_Bull_returns_dict[key] > max_ROC_Bull_return:
        max_ROC_Bull_return = TROC_Bull_returns_dict[key]
        max_ROC_Bull_days = key
        max_ROC_Bull_TROC_Thresh = key
    else:
        max_ROC_Bull_return = max_ROC_Bull_return
        max_ROC_Bull_days = max_ROC_Bull_days
        max_ROC_Bull_TROC_Thresh = max_ROC_Bull_TROC_Thresh
print('The best BULL TROC return is', max_ROC_Bull_return, 'which uses', max_ROC_Bull_days, 'ROC days and', max_ROC_Bull_TROC_Thresh, 'TROC Threshold')

# %%
print(TROC_Bull_returns_dict)

# %%
#find best ROC Bear returns
max_ROC_Bear_return = 0
max_ROC_Bear_days = 0
for key in TROC_Bear_returns_dict:
    if TROC_Bear_returns_dict[key] > max_ROC_Bear_return:
        max_ROC_Bear_return = TROC_Bear_returns_dict[key]
        max_ROC_Bear_days = key
    else:
        max_ROC_Bear_return = max_ROC_Bear_return
        max_ROC_Bear_days = max_ROC_Bear_days
print('The best BEAR TROC return is', max_ROC_Bear_return, 'which uses', max_ROC_Bear_days, 'ROC days')

# %%
print(df)

# %%
out_df1.to_csv('ROC Bull.csv')
out_df2.to_csv('ROC Bear.csv')
